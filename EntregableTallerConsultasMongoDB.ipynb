# %% [markdown]
# <a href="https://colab.research.google.com/github/cam2149/Extraction_Storage/blob/main/EntregableTallerConsultasMongoDB.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <font color="green">*Para iniciar, cree su propia copia de este notebook. File> Save a Copy in Drive*</font>

# %% [markdown]
# #Práctica de MongoDB utilizando pymongo

# %% [markdown]
# A continuación se encuentran las instrucciones para instalar pymongo en notebook en Colab, la configuración de la conexión a un cluster montado en Atlas MongoDB con el fin de realizar consultas en la base de datos test.
#
# **Instrucciones**
#
# Realice cada una de las instrucciones, analice el resultado y realice las consultas propuestas al final.

# %% [markdown]
# ##1. Objetivo
#
# El objetivo de este taller es poder realizar consultas a una base de datos MongoDB montada en Atlas, utilizando pymongo

# %% [markdown]
# ##2. Configuración pymongo

# %% [markdown]
# Pymongo es una librería de Python para poder conectarnos a una base de datos MongoDB. En este ejemplo vamos a ver cómo conectarnos desde Python a MongoDB.

# %%
# !python --version
# Out:
# Python 3.10.12

# %%
# !pip install pymongo
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 18.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 307.7/307.7 kB 18.2 MB/s eta 0:00:00
# ...

# %%
import pymongo

# %% [markdown]
# ##3. Configurando la conexión a la base de datos test en el cluster en Atlas MongoDB

# %%
# Trying 3.6+ connection string
client = pymongo.MongoClient(
    "mongodb+srv://ead:ead12345@cluster0.v5rih5b.mongodb.net/?retryWrites=true&w=majority&appName=Cluster0")
db = client.ead
collection = db.users

# %%
db
# Out:
# Database(MongoClient(host=['ac-vv4a0mx-shard-00-01.v5rih5b.mongodb.net:27017', 'ac-vv4a0mx-shard-00-02.v5rih5b.mongodb.net:27017', 'ac-vv4a0mx-shard-00-00.v5rih5b.mongodb.net:27017'], document_class=dict, tz_aware=False, connect=True, retrywrites=True, w='majority', appname='Cluster0', authsource='admin', replicaset='atlas-mrr86e-shard-0', tls=True), 'ead')

# %%
list(db.users.find())
# Out:
# [{'_id': ObjectId('66b2535cc0bcf1bf786032ad'),
#   'nombre': 'Monica',
#   'apellido': 'Rojas',
#   'edad': 47,
#   'genero': 'femenino'},
#  {'_id': ObjectId('66c69ca73756af26287fb69e'),
#   'nombre': 'Andres',
#   'apellido': 'Rodriguez',
#   'edad': 37,
#   'genero': 'masculino'},
#  {'_id': ObjectId('66c69e743756af26287fb69f'),
#   'nombre': 'Felipe',
#   'apellido': 'Perez'},
#  {'_id': ObjectId('66ca25ae617e63bd422fb742'),
#   'nombre': 'Danna',
#   'apellido': 'Espinosa',
#   'edad': 21,
#   'genero': 'femenino'},
#  {'_id': ObjectId('66ca269cfe854902920261ae'),
#   'nombre': 'Monica',
#   'apellido': 'Rojas',
#   'edad': 28,
#   'genero': 'femenino'},
#  {'_id': ObjectId('66ca26b1fe854902920261af'),
#   'nombre': 'Jonathan',
#   'apellido': 'Pacheco',
#   'edad': 36,
#   'genero': 'masculino'},
#  {'_id': ObjectId('66cdf6b3cf781c0d50e9b5ae'),
#   'nombre': 'David',
#   'apellido': 'Orozco',
#   'edad': 37,
#   'genero': 'masculino'},
# ...

# %%
list(db.movies.find())
# Out:
# [{'_id': ObjectId('66bf77ed7cfcd993e3a9dd35'),
#   'title': 'West Side Story',
#   'year': 1961,
#   'rated': 'UNRATED',
#   'runtime': 152,
#   'countries': ['USA'],
#   'genres': ['Crime', 'Drama', 'Musical'],
#   'director': 'Jerome Robbins, Robert Wise',
#   'writers': ['Ernest Lehman', 'Arthur Laurents', 'Jerome Robbins'],
#   'actors': ['Natalie Wood', 'Richard Beymer', 'Russ Tamblyn', 'Rita Moreno'],
#   'plot': 'Two youngsters from rival New York City gangs fall in love, but tensions between their respective friends build toward tragedy.',
#   'poster': 'http://ia.media-imdb.com/images/M/MV5BMTM0NDAxOTI5MF5BMl5BanBnXkFtZTcwNjI4Mjg3NA@@._V1_SX300.jpg',
#   'imdb': {'id': 'tt0055614', 'rating': 7.6, 'votes': 67824},
#   'awards': {'wins': 18,
#    'nominations': 11,
#    'text': 'Won 10 Oscars. Another 18 wins & 11 nominations.'},
#   'type': 'movie'},
#  {'_id': ObjectId('66bf77ed7cfcd993e3a9dd39'),
#   'title': 'How the West Was Won',
#   'year': 1962,
# ...

# %% [markdown]
# Muestre los nombres y apellidos concatenados de los usuarios mayores de 18 años y distintos

# %%
pipeline = [
    {
        '$match': {
            'edad': {'$gt': 18}
        }
    },
    {
        '$group': {
            '_id': {
                'nombre': '$nombre',
                'apellido': '$apellido'
            },
            'count': {'$sum': 1}
        }
    },
    {
        '$project': {
            '_id': 0,
            'nombreCompleto': {'$concat': ['$_id.nombre', ' ', '$_id.apellido']},
            'count': 1
        }
    }
]

list(db.users.aggregate(pipeline))
# Out:
# [{'count': 1, 'nombreCompleto': 'Andres Borrero'},
#  {'count': 1, 'nombreCompleto': 'William  Cañas'},
#  {'count': 1, 'nombreCompleto': 'Jhonatan Estrada'},
#  {'count': 1, 'nombreCompleto': 'Michael Jackson'},
#  {'count': 1, 'nombreCompleto': 'Cristian David Gonzalez'},
#  {'count': 1, 'nombreCompleto': None},
#  {'count': 1, 'nombreCompleto': 'Ramón Villagra'},
#  {'count': 1, 'nombreCompleto': 'Danna Espinosa'},
#  {'count': 13, 'nombreCompleto': 'Monica Rojas'},
#  {'count': 1, 'nombreCompleto': 'David Orozco'},
#  {'count': 1, 'nombreCompleto': 'Albeto Giraldo'},
#  {'count': 1, 'nombreCompleto': 'Alejandro Patiño'},
#  {'count': 2, 'nombreCompleto': 'Joshua Triana'},
#  {'count': 2, 'nombreCompleto': 'Carlos Velez'},
#  {'count': 1, 'nombreCompleto': 'Jonathan Pacheco'},
#  {'count': 1, 'nombreCompleto': 'Danny Martinez'},
#  {'count': 1, 'nombreCompleto': 'Andres Rodriguez'},
#  {'count': 1, 'nombreCompleto': 'Alexandra Arenas'},
# ...

# %% [markdown]
# Consulta A: Obtener los nombres y años de las películas (title) con género (genres) igual a "Adventure" y clasificadas (rated) como PG-13, ordenadas por el título, en orden alfabético. Los resultados de la consulta A, cumplen con lo siguiente:

# %%
# prompt: Obtener los nombres y años de las películas (title) con género (genres) igual a "Adventure" y clasificadas (rated) como PG-13, ordenadas por el título, en orden alfabético.

pipeline = [
    {
        '$match': {
            'genres': 'Adventure',
            'rated': 'PG-13'
        }
    },
    {
        '$project': {
            '_id': 0,
            'title': 1,
            'year': 1
        }
    },
    {
        '$sort': {
            'title': 1
        }
    }
]

list(db.movies.aggregate(pipeline))
# Out:
# [{'title': '10,000 BC', 'year': 2008},
#  {'title': 'A.I. Artificial Intelligence', 'year': 2001},
#  {'title': 'AVP: Alien vs. Predator', 'year': 2004},
#  {'title': 'Adventures in Babysitting', 'year': 1987},
#  {'title': 'After Earth', 'year': 2013},
#  {'title': 'All Is Lost', 'year': 2013},
#  {'title': 'Babylon A.D.', 'year': 2008},
#  {'title': 'Battlefield Earth', 'year': 2000},
#  {'title': 'Big Fish', 'year': 2003},
#  {'title': 'Big Trouble in Little China', 'year': 1986},
#  {'title': "Cirque du Freak: The Vampire's Assistant", 'year': 2009},
#  {'title': 'Cutthroat Island', 'year': 1995},
#  {'title': 'DC Showcase Original Shorts Collection', 'year': 2010},
#  {'title': 'Die Another Day', 'year': 2002},
#  {'title': 'Hellboy II: The Golden Army', 'year': 2008},
#  {'title': 'I Am Number Four', 'year': 2011},
#  {'title': 'Independence Day', 'year': 1996},
#  {'title': 'Iron Man', 'year': 2008},
#  {'title': 'Iron Man 2', 'year': 2010},
# ...

# %% [markdown]
# Consulta B: Buscar películas que tengan una duración mayor a 120, que hayan sido nominadas a premios y que no sean de USA, ordenadas por clasificación y año de forma ascendente.  Sobre el resultado de la consulta B, es correcto decir sobre la información de la primera película:

# %%
# prompt: Buscar películas que tengan una duración mayor a 120, que hayan sido nominadas a premios nominations > 0 y que countries no sean de USA, ordenadas por clasificación y año de forma ascendente.

pipeline = [
    {
        '$match': {
            'runtime': {'$gt': 120},
            'awards.nominations': {'$gt': 0},
            'countries': {'$ne': 'USA'}
        }
    },
    {
        '$project': {
            '_id': 0,
            'title': 1,
            'rated': 1,
            'year': 1,
            'runtime': 1,
            'countries': 1,
            'awards':1,
            'genres':1
        }
    },
    {
        '$sort': {
            'rated': 1,
            'year': 1
        }
    }
]

list(db.movies.aggregate(pipeline))
# Out:
# [{'title': 'I Am Cuba',
#   'year': 1964,
#   'rated': None,
#   'runtime': 141,
#   'countries': ['Cuba', 'Soviet Union'],
#   'genres': ['Drama', 'Music', 'War'],
#   'awards': {'wins': 2, 'nominations': 1, 'text': '2 wins & 1 nomination.'}},
#  {'title': 'Inochi bô ni furô',
#   'year': 1971,
#   'rated': None,
#   'runtime': 121,
#   'countries': ['Japan'],
#   'genres': ['Crime', 'Drama'],
#   'awards': {'wins': 6, 'nominations': 1, 'text': '6 wins & 1 nomination.'}},
#  {'title': 'Office Romance',
#   'year': 1977,
#   'rated': None,
#   'runtime': 159,
#   'countries': ['Soviet Union'],
#   'genres': ['Comedy', 'Romance'],
#   'awards': {'wins': 0, 'nominations': 1, 'text': '1 nomination.'}},
#  {'title': 'Muqaddar Ka Sikandar',
#   'year': 1978,
#   'rated': None,
#   'runtime': 189,
#   'countries': ['India'],
#   'genres': ['Romance'],
#   'awards': {'wins': 0, 'nominations': 1, 'text': '1 nomination.'}},
#  {'title': 'Yasha-ga-ike',
#   'year': 1979,
#   'rated': None,
# ...

# %% [markdown]
# Consulta C: Buscar películas en las que haya participado como actor "Brad Pitt" o como escritor "Quentin Tarantino" y que tengan una calificación de IMDb superior a 6.5. Los resultados de la consulta C, cumplen con lo siguiente:

# %%
print(list(db.movies.find())[0])
# Out:
# {'_id': ObjectId('66bf77ed7cfcd993e3a9dd35'), 'title': 'West Side Story', 'year': 1961, 'rated': 'UNRATED', 'runtime': 152, 'countries': ['USA'], 'genres': ['Crime', 'Drama', 'Musical'], 'director': 'Jerome Robbins, Robert Wise', 'writers': ['Ernest Lehman', 'Arthur Laurents', 'Jerome Robbins'], 'actors': ['Natalie Wood', 'Richard Beymer', 'Russ Tamblyn', 'Rita Moreno'], 'plot': 'Two youngsters from rival New York City gangs fall in love, but tensions between their respective friends build toward tragedy.', 'poster': 'http://ia.media-imdb.com/images/M/MV5BMTM0NDAxOTI5MF5BMl5BanBnXkFtZTcwNjI4Mjg3NA@@._V1_SX300.jpg', 'imdb': {'id': 'tt0055614', 'rating': 7.6, 'votes': 67824}, 'awards': {'wins': 18, 'nominations': 11, 'text': 'Won 10 Oscars. Another 18 wins & 11 nominations.'}, 'type': 'movie'}

# %%
# prompt: Buscar películas en las que haya participado como actor "Brad Pitt" o como escritor "Quentin Tarantino" y que tengan una calificación de IMDb superior a 6.5

pipeline = [
    {
        '$match': {
            '$or': [
                {'actors': 'Brad Pitt'},
                {'writers': 'Quentin Tarantino'}
            ],
            'imdb.rating': {'$gt': 6.5}
        }
    },
    {
        '$project': {
            '_id': 0,
            'title': 1,
            'actors': 1,
            'writers': 1,
            'imdb.rating': 1,
            'genres':1,
            'rated':1,
            'year':1
        }
    },
    {
        '$limit': 3
    },
    {
        '$sort': {
            'title': 1
        }
    }
]

list(db.movies.aggregate(pipeline))
# Out:
# [{'title': 'The Tree of Life',
#   'year': 2011,
#   'rated': 'PG-13',
#   'genres': ['Drama', 'Fantasy'],
#   'writers': ['Terrence Malick'],
#   'actors': ['Brad Pitt', 'Sean Penn', 'Jessica Chastain', 'Hunter McCracken'],
#   'imdb': {'rating': 6.7}},
#  {'title': 'True Romance',
#   'year': 1993,
#   'rated': 'R',
#   'genres': ['Crime', 'Drama', 'Romance'],
#   'writers': ['Quentin Tarantino'],
#   'actors': ['Christian Slater',
#    'Patricia Arquette',
#    'Dennis Hopper',
#    'Val Kilmer'],
#   'imdb': {'rating': 8}},
#  {'title': 'World War Z',
#   'year': 2013,
#   'rated': 'PG-13',
#   'genres': ['Action', 'Adventure', 'Horror'],
#   'writers': ['Matthew Michael Carnahan',
#    'Drew Goddard',
#    'Damon Lindelof',
#    'Matthew Michael Carnahan',
#    'J. Michael Straczynski',
#    'Max Brooks'],
#   'actors': ['Brad Pitt',
#    'Mireille Enos',
#    'Daniella Kertesz',
#    'James Badge Dale'],
#   'imdb': {'rating': 7}}]

# %%
# prompt: Mostrar el título de la película que ha obtenido más premios awards.wins

pipeline = [
    {
        '$group': {
            '_id': '$title',
            'totalWins': {'$sum': '$awards.wins'}
        }
    },
    {
        '$sort': {
            'totalWins': -1
        }
    },
    {
        '$project': {
            '_id': 0,
            'title': '$_id',
            'totalWins': 1
        }
    },
    {
        '$limit': 1
    }
]

result = list(db.movies.aggregate(pipeline))
if result:
  print(result[0]['title'])
  print(result[0]['totalWins'])
else:
  print("No movies found.")
# Out:
# No Country for Old Men
# 148

# %% [markdown]
# Obtener el nombre, año y duración de las películas que no son de “France” ni de “USA” y que han ganado más de 2 premios. Los resultados deben ir ordenados de forma ascendente de acuerdo al año

# %%
# prompt: Obtener el nombre, año y duración de las películas que no son de “France” ni de “USA” y que han ganado más de 2 premios. Los resultados deben ir ordenados de forma ascendente de acuerdo al año

pipeline = [
    {
        '$match': {
            'countries': {
                '$nin': ['France', 'USA']
            },
            'awards.wins': {
                '$gt': 2
            }
        }
    },
    {
        '$project': {
            '_id': 0,
            'title': 1,
            'year': 1,
            'runtime': 1,
            'countries': 1,
            'awards': 1
        }
    },
    {
        '$sort': {
            'year': 1
        }
    },
    {
        '$limit': 1
    },
]

list(db.movies.aggregate(pipeline))
# Out:
# [{'title': 'La Strada',
#   'year': 1954,
#   'runtime': 108,
#   'countries': ['Italy'],
#   'awards': {'wins': 11,
#    'nominations': 4,
#    'text': 'Won 1 Oscar. Another 11 wins & 4 nominations.'}}]

# %% [markdown]
# Consulta F: Muestre la cantidad de películas producidas por año. Presente los resultados ordenados de mayor a menor por la cantidad de películas

# %%
# prompt: Muestre la cantidad de películas producidas por año. Presente los resultados ordenados de mayor a menor por la cantidad de películas

pipeline = [
    {
        '$group': {
            '_id': '$year',
            'count': {'$sum': 1}
        }
    },
    {
        '$sort': {
            'count': -1
        }
    },
    {
        '$project': {
            '_id': 0,
            'year': '$_id',
            'count': 1
        }
    },
    {
        '$limit': 10
    }
]

list(db.movies.aggregate(pipeline))
# Out:
# [{'count': 127, 'year': 2013},
#  {'count': 105, 'year': 2010},
#  {'count': 103, 'year': 2012},
#  {'count': 102, 'year': 2011},
#  {'count': 100, 'year': 2014},
#  {'count': 97, 'year': 2007},
#  {'count': 89, 'year': 2009},
#  {'count': 80, 'year': 2006},
#  {'count': 75, 'year': 2008},
#  {'count': 73, 'year': 2005}]

# %% [markdown]
# Consulta G: Obtener los 5 países cuyas películas han recibido más premios (Tip: uso de $unwind).  De acuerdo con el resultado de la consulta G, entre los cinco países están los siguientes:

# %%
# prompt:  Obtener los 5 países cuyas películas han recibido más premios

pipeline = [
    {
        '$unwind': '$countries'
    },
    {
        '$group': {
            '_id': '$countries',
            'totalAwards': {'$sum': '$awards.wins'}
        }
    },
    {
        '$sort': {
            'totalAwards': -1
        }
    },
    {
        '$project': {
            '_id': 0,
            'countries': '$_id',
            'totalAwards': 1
        }
    },{
        '$limit': 5
    }
]

list(db.movies.aggregate(pipeline))
# Out:
# [{'totalAwards': 3159, 'countries': 'USA'},
#  {'totalAwards': 713, 'countries': 'France'},
#  {'totalAwards': 628, 'countries': 'UK'},
#  {'totalAwards': 367, 'countries': 'Italy'},
#  {'totalAwards': 261, 'countries': 'Spain'}]

# %% [markdown]
# Consulta H: Encontrar la cantidad de películas por género, ordenadas de mayor a menor. Según el resultado de la consulta H, el género que más se repite en las películas, es:

# %%
# prompt: Consulta H: Encontrar la cantidad de películas por género, ordenadas de mayor a menor. Según el resultado de la consulta H, el género que más se repite en las películas, es:

pipeline = [
    {
        '$unwind': '$genres'
    },
    {
        '$group': {
            '_id': '$genres',
            'count': {'$sum': 1}
        }
    },
    {
        '$sort': {
            'count': -1
        }
    },
    {
        '$project': {
            '_id': 0,
            'genres': '$_id',
            'count': 1
        }
    },
    {
        '$limit': 1
    }
]

result = list(db.movies.aggregate(pipeline))
if result:
    print(result[0]['genres'])
else:
    print("No genres found.")
# Out:
# Comedy

# %% [markdown]
# Consulta I: El pais que mas películas premiadas tiene, cuantas películas tiene. Con respecto a la consulta I, el país que más películas premiadas tiene es:

# %%
# prompt: Consulta I: El pais que mas películas premiadas tiene, cuantas películas tiene. Con respecto a la consulta I, el país que más películas premiadas tiene es:

pipeline = [
    {
        '$unwind': '$countries'
    },
    {
        '$match': {
            'awards.wins': {'$gt': 0}
        }
    },
    {
        '$group': {
            '_id': '$countries',
            'count': {'$sum': 1}
        }
    },
    {
        '$sort': {
            'count': -1
        }
    },

    {
        '$project': {
            '_id': 0,
            'country': '$_id',
            'count': 1
        }
    }, {
        '$limit': 1
    }
]

result = list(db.movies.aggregate(pipeline))
if result:
    print(result[0]['country'])
    print(result[0]['count'])
else:
    print("No country found.")
# Out:
# USA
# 351

# %% [markdown]
# Consulta F: Muestre la cantidad de películas producidas por año. Presente los resultados ordenados de mayor a menor por la cantidad de películas.

# %%
# prompt: Consulta F: Muestre la cantidad de películas producidas por año. Presente los resultados ordenados de mayor a menor por la cantidad de películas.

pipeline = [
    {
        '$group': {
            '_id': '$year',
            'count': {'$sum': 1}
        }
    },
    {
        '$sort': {
            'count': -1
        }
    },
    {
        '$project': {
            '_id': 0,
            'year': '$_id',
            'count': 1
        }
    }
]

list(db.movies.aggregate(pipeline))
# Out:
# [{'count': 127, 'year': 2013},
#  {'count': 105, 'year': 2010},
#  {'count': 103, 'year': 2012},
#  {'count': 102, 'year': 2011},
#  {'count': 100, 'year': 2014},
#  {'count': 97, 'year': 2007},
#  {'count': 89, 'year': 2009},
#  {'count': 80, 'year': 2006},
#  {'count': 75, 'year': 2008},
#  {'count': 73, 'year': 2015},
#  {'count': 73, 'year': 2005},
#  {'count': 65, 'year': 2004},
#  {'count': 61, 'year': 2003},
#  {'count': 60, 'year': 2002},
#  {'count': 55, 'year': 2000},
#  {'count': 53, 'year': 2001},
#  {'count': 50, 'year': 1999},
#  {'count': 36, 'year': 1986},
#  {'count': 35, 'year': 1994},
#  {'count': 35, 'year': 1998},
#  {'count': 34, 'year': 1993},
#  {'count': 32, 'year': 1996},
#  {'count': 31, 'year': 1988},
#  {'count': 29, 'year': 1997},
#  {'count': 28, 'year': 1995},
#  {'count': 26, 'year': 1989},
#  {'count': 26, 'year': 1992},
#  {'count': 25, 'year': 1981},
#  {'count': 24, 'year': 1990},
#  {'count': 24, 'year': 1991},
#  {'count': 23, 'year': 1980},
# ...
